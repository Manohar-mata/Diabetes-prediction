# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("diabetes.csv - diabetes.csv.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df[["Pregnancies","Glucose","BloodPressure",'SkinThickness',"Insulin",'BMI']]=df[["Pregnancies","Glucose","BloodPressure",'SkinThickness',"Insulin",'BMI']].replace(0,np.nan)

# %%
df.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0    148.0           72.0           35.0      NaN  33.6
# 1          1.0     85.0           66.0           29.0      NaN  26.6
# 2          8.0    183.0           64.0            NaN      NaN  23.3
# 3          1.0     89.0           66.0           23.0     94.0  28.1
# 4          NaN    137.0           40.0           35.0    168.0  43.1
# 5          5.0    116.0           74.0            NaN      NaN  25.6
# 6          3.0     78.0           50.0           32.0     88.0  31.0
# 7         10.0    115.0            NaN            NaN      NaN  35.3
# 8          2.0    197.0           70.0           45.0    543.0  30.5
# 9          8.0    125.0           96.0            NaN      NaN   NaN
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0
# 6                     0.248   26        1
# 7                     0.134   29        0
# 8                     0.158   53        1
# 9                     0.232   54        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               657 non-null    float64
#  1   Glucose                   763 non-null    float64
#  2   BloodPressure             733 non-null    float64
#  3   SkinThickness             541 non-null    float64
#  4   Insulin                   394 non-null    float64
#  5   BMI                       757 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(7), int64(2)
# memory usage: 54.1 KB

# %%
df.dropna(axis=0,inplace=True)

# %%
df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   336.000000  336.000000     336.000000     336.000000  336.000000
# mean      3.851190  122.279762      70.244048      28.663690  155.348214
# std       3.148352   30.784649      12.363401      10.249863  118.777281
# min       1.000000   56.000000      24.000000       7.000000   15.000000
# 25%       1.000000   99.000000      62.000000      21.000000   76.000000
# 50%       3.000000  119.000000      70.000000      28.500000  125.500000
# 75%       6.000000  144.000000      78.000000      36.000000  190.000000
# max      17.000000  197.000000     110.000000      52.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  336.000000                336.000000  336.000000  336.000000
# mean    32.297321                  0.518702   31.836310    0.330357
# std      6.368558                  0.327689   10.458446    0.471043
# min     18.200000                  0.085000   21.000000    0.000000
# 25%     27.800000                  0.268000   24.000000    0.000000
# 50%     32.750000                  0.446500   28.000000    0.000000
# 75%     36.250000                  0.688250   38.000000    1.000000
# max     57.300000                  2.329000   81.000000    1.000000

# %%
sns.countplot(df["Outcome"])
# Out:
# C:\Users\INDIAN\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Outcome', ylabel='count'>

# %%
plt.boxplot(df["Glucose"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x28c3bd18d90>,
#   <matplotlib.lines.Line2D at 0x28c3bd26130>],
#  'caps': [<matplotlib.lines.Line2D at 0x28c3bd264c0>,
#   <matplotlib.lines.Line2D at 0x28c3bd26850>],
#  'boxes': [<matplotlib.lines.Line2D at 0x28c3bd18a00>],
#  'medians': [<matplotlib.lines.Line2D at 0x28c3bd26be0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x28c3bd26f70>],
#  'means': []}

# %%
# TO show the how age plays a role in getting the diabetes
age=[]
diabetes_patient=[]
diabetes_and_age={'age':age,'diabetes_patient':diabetes_patient}
for i in df['Age'].unique():
    diabetes_patient.append(df[df['Age']==i]['Outcome'].sum())
    age.append(i)
diabetes_and_age=pd.DataFrame(diabetes_and_age)
diabetes_and_age.sort_values(by=['diabetes_patient'], inplace=True)
diabetes_and_age
# Out:
#     age  diabetes_patient
# 0    21                 0
# 39   81                 0
# 37   49                 0
# 34   61                 0
# 42   63                 0
# 3    59                 1
# 32   55                 1
# 31   60                 1
# 35   44                 1
# 38   48                 1
# 10   57                 1
# 40   50                 1
# 12   56                 1
# 27   39                 1
# 33   38                 2
# 36   35                 2
# 25   37                 2
# 13   54                 2
# 29   45                 2
# 41   52                 2
# 9    22                 2
# 28   47                 2
# 22   34                 2
# 23   40                 3
# 1    26                 3
# 17   24                 3
# 16   42                 3
# 15   58                 3
# 14   30                 3
# 8    41                 3
# 7    27                 3
# 6    32                 3
# 2    53                 3
# 19   23                 3
# 26   46                 4
# 5    33                 5
# 4    51                 5
# 20   36                 5
# 18   25                 5
# 24   31                 6
# 11   28                 6
# 21   43                 7
# 30   29                 8

# %%
Pregnancies=[]
diabetes_patient=[]
diabetes_and_pregnancies={'pregnancies':Pregnancies,'diabetes_patient':diabetes_patient}
for i in df['Pregnancies'].unique():
    diabetes_patient.append(df[df['Pregnancies']==i]['Outcome'].sum())
    Pregnancies.append(i)
diabetes_and_pregnancies=pd.DataFrame(diabetes_and_pregnancies)
diabetes_and_pregnancies.sort_values(by=['diabetes_patient'],inplace=True)
diabetes_and_pregnancies
# Out:
#     pregnancies  diabetes_patient
# 6          13.0                 1
# 11         15.0                 1
# 13         17.0                 1
# 15         14.0                 1
# 5          10.0                 3
# 14         12.0                 3
# 12          6.0                 4
# 4          11.0                 5
# 7           4.0                 6
# 8           9.0                 6
# 3           5.0                 8
# 10          7.0                10
# 9           8.0                11
# 2           2.0                12
# 1           3.0                19
# 0           1.0                20

# %%
glucose=[]
daibetes_patient=[]
glucose_and_diabetes={'Glucose':glucose,'daibetes_patients':daibetes_patient}
for i in df['Glucose'].unique():
    daibetes_patient.append(df[df['Glucose']==i]['Outcome'].sum())
    glucose.append(i)
glucose_and_diabetes=pd.DataFrame(glucose_and_diabetes)
glucose_and_diabetes.sort_values(by=['daibetes_patients'],inplace=True)
glucose_and_diabetes
# Out:
#     Glucose  daibetes_patients
# 0      89.0                  0
# 28    110.0                  0
# 59     75.0                  0
# 30    123.0                  0
# 31     81.0                  0
# ..      ...                ...
# 20    187.0                  4
# 44    173.0                  4
# 37    155.0                  4
# 61    181.0                  4
# 62    128.0                  5
#
# [111 rows x 2 columns]

# %%
fig,axs=plt.subplots(1,3,figsize=(18,8))
axs[0].bar(diabetes_and_age['age'],diabetes_and_age['diabetes_patient'])
axs[1].bar(diabetes_and_pregnancies['pregnancies'],diabetes_and_pregnancies['diabetes_patient'])
axs[2].bar(glucose_and_diabetes['Glucose'],glucose_and_diabetes['daibetes_patients'])
plt.show()

# %%
sns.jointplot(data=df[['Age','Bdata:image/png;base64,...loodPressure', 'Glucose','BMI']],height=10, ratio=5, color="r")
plt.title("Plotting the jointplot")
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
for i in df.columns:
    plt.figure()
    sns.distplot(df[i])
# Out:
# C:\Users\INDIAN\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\INDIAN\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\INDIAN\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\INDIAN\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\INDIAN\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\INDIAN\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\INDIAN\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\INDIAN\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\INDIAN\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
for i in df.columns:
    plt.figure()
    df[i].plot.box()

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.250519       0.298336       0.171517
# Glucose                      0.250519  1.000000       0.237707       0.204054
# BloodPressure                0.298336  0.237707       1.000000       0.208907
# SkinThickness                0.171517  0.204054       0.208907       1.000000
# Insulin                      0.101397  0.587348       0.100835       0.202180
# BMI                          0.118681  0.199681       0.266723       0.639901
# DiabetesPedigreeFunction     0.025755  0.117859       0.016021       0.132766
# Age                          0.675202  0.375484       0.343854       0.205159
# Outcome                      0.309008  0.515654       0.241377       0.266678
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies               0.101397  0.118681                  0.025755
# Glucose                   0.587348  0.199681                  0.117859
# BloodPressure             0.100835  0.266723                  0.016021
# SkinThickness             0.202180  0.639901                  0.132766
# Insulin                   1.000000  0.246661                  0.179846
# BMI                       0.246661  1.000000                  0.126696
# DiabetesPedigreeFunction  0.179846  0.126696                  1.000000
# Age                       0.242045  0.128185                  0.074231
# Outcome                   0.333050  0.278716                  0.188130
#
#                                Age   Outcome
# Pregnancies               0.675202  0.309008
# Glucose                   0.375484  0.515654
# BloodPressure             0.343854  0.241377
# SkinThickness             0.205159  0.266678
# Insulin                   0.242045  0.333050
# BMI                       0.128185  0.278716
# DiabetesPedigreeFunction  0.074231  0.188130
# Age                       1.000000  0.391538
# Outcome                   0.391538  1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
X=df.drop('Outcome',axis=1)
y=df['Outcome']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=0)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (235, 8)
# (235,)
# (101, 8)
# (101,)

# %%
X_test
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 128          1.0    117.0           88.0           24.0    145.0  34.5
# 126          3.0    120.0           70.0           30.0    135.0  42.9
# 638          7.0     97.0           76.0           32.0     91.0  40.9
# 620          2.0    112.0           86.0           42.0    160.0  38.4
# 457          5.0     86.0           68.0           28.0     71.0  30.2
# ..           ...      ...            ...            ...      ...   ...
# 326          1.0    122.0           64.0           32.0    156.0  35.1
# 228          4.0    197.0           70.0           39.0    744.0  36.7
# 199          4.0    148.0           60.0           27.0    318.0  30.9
# 393          4.0    116.0           72.0           12.0     87.0  22.1
# 281         10.0    129.0           76.0           28.0    122.0  35.9
#
#      DiabetesPedigreeFunction  Age
# 128                     0.403   40
# 126                     0.452   30
# 638                     0.871   32
# 620                     0.246   28
# 457                     0.364   24
# ..                        ...  ...
# 326                     0.692   30
# 228                     2.329   31
# 199                     0.150   29
# 393                     0.463   37
# 281                     0.280   39
#
# [101 rows x 8 columns]

# %%
X_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 669          9.0    154.0           78.0           30.0    100.0  30.9
# 110          3.0    171.0           72.0           33.0    135.0  33.3
# 458         10.0    148.0           84.0           48.0    237.0  37.6
# 486          1.0    139.0           62.0           41.0    480.0  40.7
# 520          2.0     68.0           70.0           32.0     66.0  25.0
# ..           ...      ...            ...            ...      ...   ...
# 738          2.0     99.0           60.0           17.0    160.0  36.6
# 431          3.0     89.0           74.0           16.0     85.0  30.4
# 282          7.0    133.0           88.0           15.0    155.0  32.4
# 112          1.0     89.0           76.0           34.0     37.0  31.2
# 389          3.0    100.0           68.0           23.0     81.0  31.6
#
#      DiabetesPedigreeFunction  Age
# 669                     0.164   45
# 110                     0.199   24
# 458                     1.001   51
# 486                     0.536   21
# 520                     0.187   25
# ..                        ...  ...
# 738                     0.453   21
# 431                     0.551   38
# 282                     0.262   37
# 112                     0.192   23
# 389                     0.949   28
#
# [235 rows x 8 columns]

# %%
y_train
# Out:
# 669    0
# 110    1
# 458    1
# 486    0
# 520    0
#       ..
# 738    0
# 431    0
# 282    0
# 112    0
# 389    0
# Name: Outcome, Length: 235, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.fit_transform(X_test)

# %%
X_test
# Out:
# array([
#         -4.63786487e-02, -5.07453674e-01],
#        [-9.05942412e-01, -5.65950103e-01, -9.54603977e-01,
#         -1.97474041e+00,  1.21605356e-01, -1.22177296e+00,
#          1.00513230e+00, -1.11881933e+00],
#        [ 4.34719619e-01,  2.07068793e+00,  3.23473924e-01,
#         -1.34270839e-01,  3.28375407e-01,  1.81153749e+00,
#          1.23498520e+00,  2.14179752e+00],
#        [ 3.11604368e+00,  9.21384171e-01,  1.28203235e+00,
#          8.34397357e-01, -2.25768328e-01,  1.31154126e+00,
#          1.60486343e+00,  7.15277644e-01],
#        [-9.05942412e-01, -7.68768413e-01, -3.35100004e+00,
#          9.31264176e-01, -6.97204043e-01,  1.76153787e+00,
#         -1.01334601e+00,  1.03911985e-01],
#        [ 3.78637470e+00,  3.46732292e-01, -1.55805289e-01,
#          3.50063259e-01, -4.73892389e-01,  7.28212329e-01,
#         -1.09260563e+00,  1.12285475e+00],
#        [-9.05942412e-01, -5.99753154e-01, -9.54603977e-01,
#          1.70619873e+00,  8.85221483e-02,  4.61547674e-01,
#         -4.00404950e-01, -8.13136504e-01],
#        [-5.70776904e-01, -9.27073793e-02, -1.91316240e+00,
#          3.50063259e-01, -1.89982779e-02,  1.56153938e+00,
#         -1.22996281e-01, -6.09347951e-01],
#        [ 9.95541112e-02, -9.27073793e-02,  6.42993400e-01,
#         -1.29667267e+00,  7.19805443e-02, -1.21781260e-01,
#         -3.26429305e-01,  2.05806261e-01],
#        [-9.05942412e-01, -1.26510431e-01, -6.35084502e-01,
#          3.50063259e-01, -9.34354960e-02,  3.94881510e-01,
#          3.31425538e-01, -2.01770845e-01],
#        [ 9.95541112e-02,  2.40871844e+00, -1.55805289e-01,
#          1.02813100e+00,  4.76979609e+00,  6.61546165e-01,
#          4.65635878e+00, -9.98765681e-02],
#        [ 9.95541112e-02,  7.52368912e-01, -9.54603977e-01,
#         -1.34270839e-01,  1.24643443e+00, -3.05113210e-01,
#         -1.10053159e+00, -3.03665121e-01],
#        [ 9.95541112e-02, -3.29328741e-01,  3.95444895e-03,
#         -1.58727313e+00, -6.64120835e-01, -1.77176881e+00,
#         -2.73589558e-01,  5.11489091e-01],
#        [ 2.11054716e+00,  1.10110931e-01,  3.23473924e-01,
#         -3.74040194e-02, -3.74642765e-01,  5.28213838e-01,
#         -7.57073238e-01,  7.15277644e-01]])

# %%
X_train
# Out:
# array([[ 1.5851818 ,  1.06765585,  0.69605508, ..., -0.18636274,
#         -1.11320847,  1.23589559],
#        [-0.28520007,  1.61420699,  0.20410638, ...,  0.18295766,
#         -0.99660243, -0.72650619],
#        [ 1.89691211,  0.87475544,  1.18800379, ...,  0.84465671,
#          1.67534175,  1.79658182],
#        ...,
#        [ 0.96172118,  0.39250444,  1.51596959, ...,  0.04446251,
#         -0.78671155,  0.48831396],
#        [-0.9086607 , -1.02209852,  0.53207218, ..., -0.14019769,
#         -1.01992364, -0.8199539 ],
#        [-0.28520007, -0.66844778, -0.12385943, ..., -0.07864429,
#          1.50209849, -0.35271538]])

# %%
from sklearn.linear_model import LinearRegression
LinReg=LinearRegression()

# %%
LinReg=LinReg.fit(X_train,y_train)

# %%
LinReg.coef_
# Out:
# array([0.08898396, 0.18487303, 0.01215343, 0.03903087, 0.04594955,
#        0.04146839, 0.07156973, 0.00172488])

# %%
LinReg.intercept_
# Out:
# 0.29787234042553196

# %%
y_pred1=LinReg.predict(X_test)

# %%
y_pred1
# Out:
# array([ 0.13585941,  0.28122865,  0.31921351,  0.20140933, -0.0108919 ,
#        -0.08879334,  0.49023435,  0.28268496,  0.37820171,  0.57232894,
#         0.01360776,  0.82551331, -0.06267711, -0.14089079, -0.18456061,
#         0.30437099,  0.31643671,  0.15930142,  0.39507349,  0.44893261,
#         0.03596584,  0.30081021,  0.17983646, -0.07726021,  0.33825959,
#         0.27723801,  0.60086282,  0.40059221,  0.135394  ,  0.56536683,
#         0.04925207,  0.61647603,  0.64514804,  0.37993502,  0.28137476,
#         0.4739799 ,  0.01783072,  0.38496984,  0.10722995,  0.43554972,
#         0.40474093,  0.22028476,  0.48640366,  0.86664086,  0.38544815,
#         0.06285976, -0.17639909,  0.28349993,  0.82172873,  0.41777157,
#         0.76360718,  0.44845643, -0.0840282 ,  0.2923601 ,  0.0662128 ,
#         0.68688904, -0.08691184,  0.4380333 ,  0.13305902, -0.15708118,
#         0.6421971 ,  0.70389172,  0.29326534,  0.7827489 , -0.17246946,
#         0.03737555,  0.58601074, -0.1727256 ,  0.90730032, -0.0322788 ,
#         0.26545138,  0.53700755, -0.01852902,  0.19431404,  0.12672076,
#         1.10418788,  0.05018053, -0.01752362,  0.30458363,  0.11416203,
#        -0.132479  , -0.01892269,  0.62508938, -0.19093133, -0.3868835 ,
#         0.38299384,  0.47376761,  0.28040763,  0.04888152,  0.90035251,
#         0.95374461,  0.03942164,  0.64283204,  0.15452029,  0.27438276,
#         0.22204621,  0.23526824,  1.36995872,  0.39431338,  0.06125554,
#         0.46024487])

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
r2_score(y_test,y_pred1)
# Out:
# 0.1042061633461483

# %%
mean_absolute_error(y_test,y_pred1)
# Out:
# 0.36618296493611024

# %%
mean_squared_error(y_test,y_pred1)
# Out:
# 0.21602321715209044

# %%
from sklearn.linear_model import LogisticRegression
lg=LogisticRegression()
lg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lg.predict(X_test)

# %%
y_pred.shape
# Out:
# (101,)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[54,  6],
#        [24, 17]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.7029702970297029

# %%
recall_score(y_test,y_pred)
# Out:
# 0.4146341463414634

# %%
precision_score(y_test,y_pred)
# Out:
# 0.7391304347826086

# %%
from sklearn.tree import DecisionTreeRegressor
DTS= DecisionTreeRegressor()  
DTS.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
predict_3=DTS.predict(X_test)

# %%
accuracy_score(y_test,predict_3)
# Out:
# 0.693069306930693

# %%
from sklearn.ensemble import RandomForestClassifier
Rf=RandomForestClassifier(n_estimators = 50, max_depth=2, random_state=0)

# %%
Rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=2, n_estimators=50, random_state=0)

# %%
y_pred3=Rf.predict(X_test)

# %%
confusion_matrix(y_test,y_pred3)
# Out:
# array([[57,  3],
#        [27, 14]], dtype=int64)

# %%
accuracy_score(y_test,y_pred3)
# Out:
# 0.7029702970297029

# %%
from sklearn.metrics import f1_score
f1_score(y_test,y_pred3)
# Out:
# 0.48275862068965514

# %%
precision_score(y_test,y_pred3)
# Out:
# 0.8235294117647058

# %%
from sklearn.naive_bayes import GaussianNB
NB=GaussianNB()

# %%
NB.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred4=NB.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.90      0.78        60
#            1       0.74      0.41      0.53        41
#
#     accuracy                           0.70       101
#    macro avg       0.72      0.66      0.66       101
# weighted avg       0.71      0.70      0.68       101

# %%
accuracy_score(y_test,y_pred4)
# Out:
# 0.6831683168316832

# %%
precision_score(y_test,y_pred4)
# Out:
# 0.6451612903225806

# %%
from sklearn.svm import SVC
svm=SVC()
svm.fit(X_train,y_train)
# Out:
# SVC()

# %%
y_pred5=svm.predict(X_test)

# %%
accuracy_score(y_test,y_pred5)
# Out:
# 0.7128712871287128

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN = KNeighborsClassifier(n_neighbors= 5)
KNN.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred6=KNN.predict(X_test)

# %%
confusion_matrix(y_test,y_pred6)
# Out:
# array([[53,  7],
#        [22, 19]], dtype=int64)

# %%
accuracy_score(y_test,y_pred6)
# Out:
# 0.7128712871287128

# %%
precision_score(y_test,y_pred6)
# Out:
# 0.7307692307692307

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold

# %%
19*3*2*30
# Out:
# 3420

# %%
KNN = KNeighborsClassifier()
k = range(1, 39, 2)
mat = ["eclediean", "manhattan", "minkowski"]
w = ["uniform", "distance"]

search_space = dict(n_neighbors = k, metric = mat, weights = w)

# %%
X_train1 = X_train[:1000]
y_train1 = y_train[:1000]

# %%
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3)
search = GridSearchCV(estimator=KNN, param_grid= search_space,cv = cv,  scoring = "accuracy")
search_result = search.fit(X_train1, y_train1)
# Out:
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# ...
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 179, in fit
#     return self._fit(X, y)
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 399, in _fit
#     self._check_algorithm_metric()
#   File "C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 342, in _check_algorithm_metric
#     raise ValueError("Metric '%s' not valid. Use "
# ValueError: Metric 'eclediean' not valid. Use sorted(sklearn.neighbors.VALID_METRICS['brute']) to get valid options. Metric can also be a callable function.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\INDIAN\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:922: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan 0.7009058  0.7009058  0.73327295 0.72759662
#  0.75561594 0.75416667 0.76310386 0.75736715 0.76594203 0.76032609
#  0.77741546 0.76908213 0.78695652 0.78001208 0.79263285 0.78985507
#  0.79842995 0.79559179 0.80259662 0.79975845 0.80120773 0.79836957
#  0.79541063 0.79692029 0.7968599  0.79263285 0.80410628 0.79987923
#  0.80833333 0.802657   0.80688406 0.79842995 0.80253623 0.79698068
#  0.79993961 0.79281401 0.8013285  0.7955314  0.72898551 0.72898551
#  0.75150966 0.74583333 0.76008454 0.75434783 0.76708937 0.76002415
#  0.77137681 0.76847826 0.79679952 0.7798913  0.80235507 0.79118357
#  0.81086957 0.79963768 0.80549517 0.79842995 0.80543478 0.80120773
#  0.81129227 0.80700483 0.81262077 0.81123188 0.80561594 0.80706522
#  0.80404589 0.80549517 0.80543478 0.80404589 0.80114734 0.80126812
#  0.80120773 0.802657   0.79432367 0.7942029  0.79993961 0.79842995]
#   warnings.warn(

# %%
search_result.best_score_
# Out:
# 0.8126207729468599

# %%
search_result.best_params_
# Out:
# {'metric': 'minkowski', 'n_neighbors': 23, 'weights': 'uniform'}

# %%
knn = KNeighborsClassifier(metric ='manhattan', n_neighbors = 7, weights = 'distance')
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(metric='manhattan', n_neighbors=7, weights='distance')

# %%
y_pred8 = knn.predict(X_test)
print(accuracy_score(y_test, y_pred8))
# Out:
# 0.7128712871287128
